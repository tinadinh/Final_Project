# %%
# import independencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
#Reading sample file into a dataframe
file_path = Path('../Datasource/sample_covid_dataset.csv')
cases_df = pd.read_csv(file_path)
cases_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1     _id  Row_ID  \
# 0           0             9               9            353345  353346  353346
# 1           1            15              15             35074   35075   35075
# 2           2            16              16            131940  131941  131941
# 3           3            24              24            205768  205769  205769
# 4           4            26              26            387017  387018  387018
#
#   Accurate_Episode_Date   Case_Reported_Date   Test_Reported_Date  \
# 0   2020-12-14T00:00:00  2020-12-20T00:00:00  2020-12-20T00:00:00
# 1   2020-11-08T00:00:00  2020-11-09T00:00:00  2020-11-09T00:00:00
# 2   2021-02-03T00:00:00  2021-02-05T00:00:00  2021-02-05T00:00:00
# 3   2020-12-24T00:00:00  2020-12-29T00:00:00  2020-12-29T00:00:00
# 4   2021-01-21T00:00:00  2021-01-23T00:00:00  2021-01-23T00:00:00
#
#          Specimen_Date  ...  Outcome1 Outbreak_Related Reporting_PHU_ID  \
# 0  2020-12-16T00:00:00  ...  Resolved              Yes             3895
# 1  2020-11-08T00:00:00  ...  Resolved              Yes             3895
# 2  2021-02-03T00:00:00  ...  Resolved              Yes             2246
# 3  2020-11-26T00:00:00  ...  Resolved              Yes             3895
# 4  2021-01-21T00:00:00  ...  Resolved              Yes             2246
#
#                              Reporting_PHU           Reporting_PHU_Address  \
# 0                    Toronto Public Health  277 Victoria Street, 5th Floor
# 1                    Toronto Public Health  277 Victoria Street, 5th Floor
# 2  Niagara Region Public Health Department        1815 Sir Isaac Brock Way
# 3                    Toronto Public Health  277 Victoria Street, 5th Floor
# 4  Niagara Region Public Health Department        1815 Sir Isaac Brock Way
#
#    Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0             Toronto                   M5B 1W2
# 1             Toronto                   M5B 1W2
# 2             Thorold                   L2V 4T7
# 3             Toronto                   M5B 1W2
# 4             Thorold                   L2V 4T7
#
#                                Reporting_PHU_Website Reporting_PHU_Latitude  \
# 0  www.toronto.ca/community-people/health-wellnes...              43.656591
# 1  www.toronto.ca/community-people/health-wellnes...              43.656591
# 2                        www.niagararegion.ca/health              43.116537
# 3  www.toronto.ca/community-people/health-wellnes...              43.656591
# 4                        www.niagararegion.ca/health              43.116537
#
#   Reporting_PHU_Longitude
# 0              -79.379358
# 1              -79.379358
# 2              -79.241220
# 3              -79.379358
# 4              -79.241220
#
# [5 rows x 23 columns]

# %% [markdown]
# # Cleaning Data

# %%
# Check the columns

cases_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1',
#        '_id', 'Row_ID', 'Accurate_Episode_Date', 'Case_Reported_Date',
#        'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender',
#        'Case_AcquisitionInfo', 'Outcome1', 'Outbreak_Related',
#        'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
#        'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
# Drop unrelated columns from dataframe

columns_to_drop=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.1.1','Unnamed: 0.1.1.1', '_id', 'Row_ID','Age_Group','Accurate_Episode_Date',
                'Case_Reported_Date','Test_Reported_Date','Specimen_Date', 'Case_AcquisitionInfo', 'Outcome1','Outbreak_Related',
                'Reporting_PHU_City' , 'Reporting_PHU_Postal_Code',  'Reporting_PHU_Website','Client_Gender']
                
               
cleaned_cases_df = cases_df.drop(columns= columns_to_drop)

# %%
cleaned_cases_df.columns
# Out:
# Index(['Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_Latitude', 'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
# Rename columns to short version

cleaned_cases_df = cleaned_cases_df.rename(columns={"Accurate_Episode_Date": "Date",'Reporting_PHU_ID':'PHU_id'})
cleaned_cases_df.columns
# Out:
# Index(['PHU_id', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_Latitude', 'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
cleaned_cases_df
# Out:
#        PHU_id                            Reporting_PHU  \
# 0        3895                    Toronto Public Health
# 1        3895                    Toronto Public Health
# 2        2246  Niagara Region Public Health Department
# 3        3895                    Toronto Public Health
# 4        2246  Niagara Region Public Health Department
# ...       ...                                      ...
# 13519    2253                       Peel Public Health
# 13520    2261           Sudbury & District Health Unit
# 13521    3895                    Toronto Public Health
# 13522    2253                       Peel Public Health
# 13523    2253                       Peel Public Health
#
#                 Reporting_PHU_Address  Reporting_PHU_Latitude  \
# 0      277 Victoria Street, 5th Floor               43.656591
# 1      277 Victoria Street, 5th Floor               43.656591
# 2            1815 Sir Isaac Brock Way               43.116537
# 3      277 Victoria Street, 5th Floor               43.656591
# 4            1815 Sir Isaac Brock Way               43.116537
# ...                               ...                     ...
# 13519          7120 Hurontario Street               43.647471
# 13520               1300 Paris Street               46.466092
# 13521  277 Victoria Street, 5th Floor               43.656591
# 13522          7120 Hurontario Street               43.647471
# 13523          7120 Hurontario Street               43.647471
#
#        Reporting_PHU_Longitude
# 0                   -79.379358
# 1                   -79.379358
# 2                   -79.241220
# 3                   -79.379358
# 4                   -79.241220
# ...                        ...
# 13519               -79.708893
# 13520               -80.998059
# 13521               -79.379358
# 13522               -79.708893
# 13523               -79.708893
#
# [13524 rows x 5 columns]

# %%
cleaned_cases_df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
cleaned_cases_df
# Out:
#       PHU_id                                      Reporting_PHU  \
# 0       3895                              Toronto Public Health
# 2       2246            Niagara Region Public Health Department
# 5       2253                                 Peel Public Health
# 6       2270                 York Region Public Health Services
# 7       2265                  Region of Waterloo, Public Health
# 8       2251                               Ottawa Public Health
# 10      2236                    Halton Region Health Department
# 13      2230                    Durham Region Health Department
# 16      2266           Wellington-Dufferin-Guelph Public Health
# 19      2268                   Windsor-Essex County Health Unit
# 23      2255                         Peterborough Public Health
# 38      2260                Simcoe Muskoka District Health Unit
# 41      2240                           Chatham-Kent Health Unit
# 42      2262                   Thunder Bay District Health Unit
# 43      2237                    Hamilton Public Health Services
# 44      2263                            Timiskaming Health Unit
# 65      2241  Kingston, Frontenac and Lennox & Addington Pub...
# 67      2243   Leeds, Grenville and Lanark District Health Unit
# 68      2247         North Bay Parry Sound District Health Unit
# 74      2238    Hastings and Prince Edward Counties Health Unit
# 79      2249                           Northwestern Health Unit
# 94      2234                      Haldimand-Norfolk Health Unit
# 124     2258                        Eastern Ontario Health Unit
# 128     2242                              Lambton Public Health
# 133     2244                       Middlesex-London Health Unit
# 216     2261                     Sudbury & District Health Unit
# 275     2235  Haliburton, Kawartha, Pine Ridge District Heal...
# 291     2233                             Grey Bruce Health Unit
# 413     5183                   Huron Perth District Health Unit
# 418     2227                           Brant County Health Unit
# 454     2256                              Porcupine Health Unit
# 506     2257            Renfrew County and District Health Unit
# 564     4913                         Southwestern Public Health
# 1182    2226                          Algoma Public Health Unit
#
#                Reporting_PHU_Address  Reporting_PHU_Latitude  \
# 0     277 Victoria Street, 5th Floor               43.656591
# 2           1815 Sir Isaac Brock Way               43.116537
# 5             7120 Hurontario Street               43.647471
# 6                 17250 Yonge Street               44.048023
# 7             99 Regina Street South               43.462876
# 8            100 Constellation Drive               45.345665
# 10                  1151 Bronte Road               43.413997
# 13            605 Rossland Road East               43.898605
# 16               160 Chancellors Way               43.524881
# 19             1005 Ouellette Avenue               42.308796
# 23                   185 King Street               44.301632
# 38                 15 Sperling Drive               44.410713
# 41             435 Grand Avenue West               42.403861
# 42               999 Balmoral Street               48.400572
# 43      110 King St. West, 2nd Floor               43.257631
# 44     247 Whitewood Avenue, Unit 43               47.509284
# 65             221 Portsmouth Avenue               44.227874
# 67             458 Laurier Boulevard               44.615843
# 68               345 Oak Street West               46.313207
# 74             179 North Park Street               44.186674
# 79           210 First Street North                49.769615
# 94               12 Gilbertson Drive               42.847825
# 124                 1000 Pitt Street               45.029152
# 128               160 Exmouth Street               42.986416
# 133                   50 King Street               42.981468
# 216                1300 Paris Street               46.466092
# 275               200 Rose Glen Road               43.968173
# 291             101 17th Street East               44.576196
# 413             653 West Gore Street               43.368662
# 418          194 Terrace Hill Street               43.151811
# 454            169 Pine Street South               48.472510
# 506            7 International Drive               45.799406
# 564               1230 Talbot Street               42.777804
# 1182               294 Willow Avenue               46.532373
#
#       Reporting_PHU_Longitude
# 0                  -79.379358
# 2                  -79.241220
# 5                  -79.708893
# 6                  -79.480239
# 7                  -80.520913
# 8                  -75.763912
# 10                 -79.744796
# 13                 -78.940341
# 16                 -80.233743
# 19                 -83.033670
# 23                 -78.321347
# 38                 -79.686306
# 41                 -82.208561
# 42                 -89.258851
# 43                 -79.871341
# 44                 -79.681632
# 65                 -76.525211
# 67                 -75.702833
# 68                 -79.467841
# 74                 -77.391446
# 79                 -94.488254
# 94                 -80.303815
# 124                -74.736298
# 128                -82.404808
# 133                -81.254016
# 216                -80.998059
# 275                -78.285792
# 291                -80.940980
# 413                -81.001913
# 418                -80.274374
# 454                -81.328750
# 506                -77.118727
# 564                -81.151156
# 1182               -84.314836

# %%
# Saving the dataframe into csv file
cleaned_cases_df.to_csv('../Datasource/PHU_locations.csv')
